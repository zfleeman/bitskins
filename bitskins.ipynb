# %% [markdown]
# ### Set Up the Environment

# %%
import pyotp
import requests as r
import json
import time

# TEST
import pandas as pd

# %% [markdown]
# ### Class

# %%
class bitSkins:
    
    def __init__(self, api = '', secret = ''):
        self.api = api
        self.secret = secret
        
        self.on_sale = []
        
        self.auth()
        
        self.payload = {
            'api_key':self.api,
            'code':self.token.now(),
        }
        
        self.bids = []
        
        self.api_counter = 0
            
    def auth(self):
        if(len(self.api) < 5):
            self.api = raw_input('API Key: ')
            
        if(len(self.secret) < 2):
            self.secret = raw_input('Secret BitSkin 2FA: ')
        else:
            self.get_token()
        
    def get_token(self):
        self.token = pyotp.TOTP(self.secret)
        
    def api_timer(self):
        self.api_counter += 1
        
        if(self.api_counter == 8):
            self.api_counter = 0
            time.sleep(1)
            
        
    def refresh_payload(self):
        
        self.payload['code'] = self.token.now()
        
        return self.payload
        
    def get_account_balance(self):
        print r.post('https://bitskins.com/api/v1/get_account_balance/', data = self.payload).content
        
    def get_all_item_prices(self):
        self.prices = r.post('https://bitskins.com/api/v1/get_all_item_prices/',self.refresh_payload()).json()['prices']
        
    def get_inventory_with_bid(self, pages = 50, per_page = 480, sort_by = 'price', order = 'desc',
                              market_hash_name = '', min_price = 0, max_price = 1000000, has_stickers = 0,
                              is_stattrak = 0, is_souvenir = 0, show_trade_delayed_items = 0):
        
        self.on_sale = []
        
        self.payload['market_hash_name'] = market_hash_name
        self.payload['per_page'] = per_page
        self.payload['sort_by'] = sort_by
        self.payload['order'] = order
        self.payload['min_price'] = min_price
        self.payload['max_price'] = max_price
        self.payload['has_stickers'] = has_stickers
        self.payload['is_stattrak'] = is_stattrak
        self.payload['is_souvenir'] = is_souvenir
        self.payload['show_trade_delayed_items'] = show_trade_delayed_items
        
        for i in range(1, pages+1):
            self.payload['page'] = i
            
            res = r.post('https://bitskins.com/api/v1/get_inventory_on_sale/', self.refresh_payload()).json()['data']['items']
            
            if(len(res) > 0):
                self.on_sale.extend(res)
                
            else:
                break
            #self.api_timer()
        
        print market_hash_name.upper() + ' // ' + str(len(self.on_sale)) + ' items match that search. ' + time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) + '\n'
            
        
    def create_bid(self, skin_name, max_price, max_wear, has_stickers, is_stattrak, is_souvenir, show_trade_delayed_items):
        bid = {
            'market_hash_name':skin_name,
            'max_price':max_price,
            'max_wear':max_wear,
            'stickers':has_stickers,
            'stattrak':is_stattrak,
            'souvenir':is_souvenir,
            'trade_delayed':show_trade_delayed_items
        }
        
        self.bids.append(bid)
        
    def buy_item(self,item_id,price):
        self.payload['item_ids'] = item_id
        self.payload['prices'] = price
        print r.post('https://bitskins.com/api/v1/buy_item', self.refresh_payload()).json()['status']
        
    def get_my_inventory(self):
        return r.post('https://bitskins.com/api/v1/get_my_inventory', self.refresh_payload()).json()
        
    def go_shopping(self,bid):
        
        
        self.get_inventory_with_bid(market_hash_name = bid['market_hash_name'], has_stickers = bid['stickers'], is_stattrak = bid['stattrak'], 
                          is_souvenir = bid['souvenir'], show_trade_delayed_items = bid['trade_delayed'])
        
        item_ids = []
        wears = []
        prices = []

        for x in self.on_sale:
            wears.append(float(x['float_value']))
            item_ids.append(x['item_id'])
            prices.append(float(x['price']))

        win_wears = [x for x in wears if x <= bid['max_wear']]
        test_price = [wears.index(w) for w in win_wears]

        for t in test_price:
            if(prices[t] <= bid['max_price']):
                self.buy_item(item_id = item_ids[t], price = prices[t])
                print 'Bought that shit. Item ' + str(item_ids[t]) + ' at $' + str(prices[t]) + '. ' + time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
                return False
                    
        return True
    
    def get_price_data_for_items_on_sale(self):
        self.market_data = r.post('https://bitskins.com/api/v1/get_all_item_prices/',self.refresh_payload()).json()['prices']
    
def main():
    creds = open('credentials.txt','r')
    api = creds.readline()
    secret = creds.readline()
    creds.close()
    
    bs = bitSkins(api = api[:-1], secret = secret)
    
    while(True):
        if(raw_input('Create a bid? y/n: ') == 'y'):
            skin_name = raw_input('What is the skin name? ')
            max_price = float(raw_input('What is your max bid price? '))
            max_wear = float(raw_input('Finally, what is the highest wear decimal you will accept? '))
            
            stick = raw_input("Stickers? y/n/eh: ")

            if(stick == 'y'):
                has_stickers = 1
            elif(stick == 'n'):
                has_stickers = -1
            elif(stick == 'eh'):
                has_stickers = 0

            stat = raw_input("StatTrak? y/n/eh: ")

            if(stat == 'y'):
                is_stattrak = 1
            elif(stat == 'n'):
                is_stattrak = -1
            elif(stat == 'eh'):
                is_stattrak = 0

            souv = raw_input("Souvenir? y/n/eh: ")

            if(souv == 'y'):
                is_souvenir = 1
            elif(souv == 'n'):
                is_souvenir = -1
            elif(souv == 'eh'):
                is_souvenir = 0

            td = raw_input("Include trade-delayed items in search? y/n: ")

            if(td == 'y'):
                show_trade_delayed_items = 0
            elif(td == 'n'):
                show_trade_delayed_items = -1        

            bs.create_bid(skin_name, max_price, max_wear, has_stickers, is_stattrak, is_souvenir, show_trade_delayed_items)
            
            
        else:
            break
            
    while(True):
        
        for bid in bs.bids:
            kill = bs.go_shopping(bid)
            if(not kill):
                del bs.bids[bs.bids.index(bid)]
                
        if(len(bs.bids) == 0):
            exit()

# %%
bs = bitSkins(api = '', secret = '')
bs.get_price_data_for_items_on_sale()
pd.DataFrame(bs.market_data).to_csv(time.strftime("%Y-%m-%d_%H_%M_%S", time.localtime())+ '.csv',encoding = 'utf-8',index = False)

# %%
bs = bitSkins(api = '', secret = '')
b = bs.get_my_inventory()

# %%
b
# Out:
# {u'data': {u'app_id': u'730',
#   u'bitskins_inventory': {u'items': [{u'app_id': u'730',
#      u'asset_ids': [u'14669148678'],
#      u'class_id': u'2933241068',
#      u'context_id': u'2',
#      u'created_at': [1532383292],
#      u'float_values': [u'0.12372398'],
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXH5ApeO4YmlhxYQknCRvCo04DEVlxkKgpopb3wflFf0v73cC9P9eOlnImFksj4OrzZgiVQuJJw077FoIr3iQPnqhY5MD-gIdXGewU4ZQ3QrlW9lerojZ--v5rK1zI97cHouWKJ/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561198399819015A%asset_id%D2449960871156172595',
#      u'inspectable': True,
#      u'instance_id': u'302028390',
#      u'is_featured': [False],
#      u'item_class': None,
#      u'item_ids': [u'14669148678'],
#      u'item_itemset': u'The Bank Collection',
#      u'item_quality': u'Normal',
#      u'item_rarity': u'Consumer Grade',
#      u'item_type': u'Rifle',
#      u'item_weapon': u'SG 553',
#      u'market_hash_name': u'SG 553 | Army Sheen (Minimal Wear)',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'prices': [u'0.01'],
#      u'recent_sales_info': {u'average_price': u'0.01', u'hours': u'79.03'},
#      u'stickers': None,
#      u'suggested_price': u'0.03',
#      u'tags': {u'exterior': u'Minimal Wear',
#       u'itemset': u'The Bank Collection',
#       u'quality': u'Normal',
#       u'rarity': u'Consumer Grade',
#       u'type': u'Rifle',
#       u'weapon': u'SG 553'},
#      u'updated_at': [0],
#      u'withdrawable_at': [1533020399]},
#     {u'app_id': u'730',
#      u'asset_ids': [u'14669148692'],
#      u'class_id': u'2933259656',
#      u'context_id': u'2',
#      u'created_at': [1532383292],
#      u'float_values': [u'0.06888559'],
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXH5ApeO4YmlhxYQknCRvCo04DEVlxkKgpopamie19fwPz3fDJR_-O6nYeDg7mjZ-yExW9Qu5wkj7-W8dis2AXk-kFqamHwLNLDcA5rYArW-VC9kOzqm9bi61mW1oPB/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561198399819015A%asset_id%D7848875088911274688',
#      u'inspectable': True,
#      u'instance_id': u'302028390',
#      u'is_featured': [False],
#      u'item_class': None,
#      u'item_ids': [u'14669148692'],
#      u'item_itemset': u'The Safehouse Collection',
#      u'item_quality': u'Normal',
#      u'item_rarity': u'Consumer Grade',
#      u'item_type': u'Sniper Rifle',
#      u'item_weapon': u'SSG 08',
#      u'market_hash_name': u'SSG 08 | Blue Spruce (Factory New)',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'prices': [u'0.11'],
#      u'recent_sales_info': {u'average_price': u'0.11', u'hours': u'46.65'},
#      u'stickers': None,
#      u'suggested_price': u'0.24',
#      u'tags': {u'exterior': u'Factory New',
#       u'itemset': u'The Safehouse Collection',
#       u'quality': u'Normal',
#       u'rarity': u'Consumer Grade',
#       u'type': u'Sniper Rifle',
#       u'weapon': u'SSG 08'},
#      u'updated_at': [0],
#      u'withdrawable_at': [1533020399]},
#     {u'app_id': u'730',
#      u'asset_ids': [u'14669148698'],
#      u'class_id': u'2933241809',
#      u'context_id': u'2',
#      u'created_at': [1532383292],
#      u'float_values': [u'-1.00000'],
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/IzMF03bi9WpSBq-S-ekoE33L-iLqGFHVaU25ZzQNQcXdB2ozio1RrlIWFK3UfvMYB8UsvjiMXojflsZalyxSh31CIyHz2GZ-KuFpPsrTzBG0pe2BEHXlJjadf3HcTQswSrJbPD6IrTak5O6dQDjPRbklQVpSf_BR9zAfPsiNPRIjlNlc7Wa3m0tvEwMkZsxWfBbmnSxKNeh2vjq5YzI/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561198399819015A%asset_id%D7397425220654869358',
#      u'inspectable': True,
#      u'instance_id': u'302028390',
#      u'is_featured': [False],
#      u'item_class': None,
#      u'item_ids': [u'14669148698'],
#      u'item_itemset': None,
#      u'item_quality': u'Normal',
#      u'item_rarity': u'Base Grade',
#      u'item_type': u'Graffiti',
#      u'item_weapon': None,
#      u'market_hash_name': u'Sealed Graffiti | Keep the Change (Battle Green)',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'prices': [u'0.03'],
#      u'recent_sales_info': None,
#      u'stickers': None,
#      u'suggested_price': u'0.03',
#      u'tags': {u'quality': u'Normal',
#       u'rarity': u'Base Grade',
#       u'spraycolorcategory': u'Battle Green',
#       u'type': u'Graffiti'},
#      u'updated_at': [0],
#      u'withdrawable_at': [1533020399]},
#     {u'app_id': u'730',
#      u'asset_ids': [u'14669148710'],
#      u'class_id': u'2933259743',
#      u'context_id': u'2',
#      u'created_at': [1532383292],
#      u'float_values': [u'0.72269988'],
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXH5ApeO4YmlhxYQknCRvCo04DEVlxkKgpopbmkOVUw7ODYTjBH_9SJh4GFk8j8NrrHjyUDsZwi3bqX9tygjVGx_ktpZzjyJ4XHd1I-MljT8ge3xr3sgpO-ucjK1zI97Sewuus7/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561198399819015A%asset_id%D10142680618071015794',
#      u'inspectable': True,
#      u'instance_id': u'302028390',
#      u'is_featured': [False],
#      u'item_class': None,
#      u'item_ids': [u'14669148710'],
#      u'item_itemset': u'The Dust 2 Collection',
#      u'item_quality': u'Normal',
#      u'item_rarity': u'Consumer Grade',
#      u'item_type': u'Sniper Rifle',
#      u'item_weapon': u'SCAR-20',
#      u'market_hash_name': u'SCAR-20 | Sand Mesh (Battle-Scarred)',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'prices': [u'0.03'],
#      u'recent_sales_info': {u'average_price': u'0.03', u'hours': u'0.02'},
#      u'stickers': None,
#      u'suggested_price': u'0.03',
#      u'tags': {u'exterior': u'Battle-Scarred',
#       u'itemset': u'The Dust 2 Collection',
#       u'quality': u'Normal',
#       u'rarity': u'Consumer Grade',
#       u'type': u'Sniper Rifle',
#       u'weapon': u'SCAR-20'},
#      u'updated_at': [0],
#      u'withdrawable_at': [1533020399]}],
#    u'items_per_page': 5000,
#    u'page': 1,
#    u'status': u'success',
#    u'total_items': 4,
#    u'total_price': u'0.18'},
#   u'context_id': u'2',
#   u'pending_withdrawal_from_bitskins': {u'items': [{u'app_id': u'730',
#      u'asset_id': u'14659202929',
#      u'attempting_to_send_offer': False,
#      u'bot_uid': u'76561198384765780',
#      u'class_id': u'2927121257',
#      u'context_id': u'2',
#      u'error_correction_details': {u'is_error_corrected': False,
#       u'previous_item_id': None},
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXH5ApeO4YmlhxYQknCRvCo04DEVlxkKgpou-6kejhz2v_Nfz5H_uOxh7-Gw_alDKjZl39F7ddOh-zF_Jn4xlbt-UNqZm-icYPGdQ49MlrT_FHrxLzph8S6tJSdnCBl6SN2tyvZyxSpwUYbmAd1EK0/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561198384765780A%asset_id%D5495702621823688674',
#      u'inspectable': True,
#      u'instance_id': u'188530170',
#      u'item_id': u'14659202929',
#      u'item_type': u'Rifle',
#      u'last_price': u'5.79',
#      u'market_hash_name': u'StatTrak\u2122 M4A1-S | Leaded Glass (Field-Tested)',
#      u'suggested_price': u'9.57',
#      u'trade_token': u'1328096a7504a971',
#      u'type': u'purchased',
#      u'withdrawable_at': 1532674799}],
#    u'status': u'success',
#    u'total_items': 1},
#   u'steam_inventory': {u'fresh_or_cached': u'cached',
#    u'items': [{u'app_id': u'730',
#      u'asset_ids': [u'14666248870'],
#      u'class_id': u'1923037342',
#      u'context_id': u'2',
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXU5A1PIYQNqhpOSV-fRPasw8rsVFx5KAVo5PSkKV4xhfGfKTgVvIXlxNPSwaOmMLiGwzgJvJMniO-Zoo_z2wXg-EVvfSmtc78HsNoy/256fx256f',
#      u'inspect_link': None,
#      u'inspectable': False,
#      u'instance_id': u'0',
#      u'is_listing_allowed': False,
#      u'item_class': None,
#      u'item_ids': [u'14666248870'],
#      u'item_itemset': u'The Gamma 2 Collection',
#      u'item_quality': u'Base Grade',
#      u'item_rarity': None,
#      u'item_type': u'Container',
#      u'item_weapon': None,
#      u'market_hash_name': u'Gamma 2 Case',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'recent_sales_info': {u'average_price': u'0.03', u'hours': u'17.72'},
#      u'stickers': None,
#      u'suggested_price': u'0.03',
#      u'tags': {u'category': u'Normal',
#       u'collection': u'The Gamma 2 Collection',
#       u'quality': u'Base Grade',
#       u'type': u'Container'}},
#     {u'app_id': u'730',
#      u'asset_ids': [u'14647598671'],
#      u'class_id': u'992123379',
#      u'context_id': u'2',
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXH5ApeO4YmlhxYQknCRvCo04DEVlxkKgpot621FA957OnHdTRD746JmImMn-O6ZezVlz4CvJYj2LqXpNmj0Vaw8kVvZG_7LNSScgJsZF_S-VO7w-e51Ij84srJoVgQJg/256fx256f',
#      u'inspect_link': u'steam://rungame/730/76561202255233023/+csgo_econ_action_preview%20S76561197992168332A%asset_id%D16315525518602690087',
#      u'inspectable': True,
#      u'instance_id': u'480085569',
#      u'is_listing_allowed': True,
#      u'item_class': None,
#      u'item_ids': [u'14647598671'],
#      u'item_itemset': u'The Gods and Monsters Collection',
#      u'item_quality': u'Industrial Grade',
#      u'item_rarity': None,
#      u'item_type': u'Sniper Rifle',
#      u'item_weapon': u'AWP',
#      u'market_hash_name': u'AWP | Sun in Leo (Minimal Wear)',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'recent_sales_info': {u'average_price': u'1.66', u'hours': u'39.24'},
#      u'stickers': None,
#      u'suggested_price': u'3.07',
#      u'tags': {u'category': u'Normal',
#       u'collection': u'The Gods and Monsters Collection',
#       u'exterior': u'Minimal Wear',
#       u'quality': u'Industrial Grade',
#       u'type': u'Sniper Rifle',
#       u'weapon': u'AWP'}},
#     {u'app_id': u'730',
#      u'asset_ids': [u'14645387751'],
#      u'class_id': u'2521767801',
#      u'context_id': u'2',
#      u'fraud_warnings': [[]],
#      u'has_buy_orders': False,
#      u'image': u'https://steamcommunity-a.akamaihd.net/economy/image/-9a81dlWLwJ2UUGcVs_nsVtzdOEdtWwKGZZLQHTxDZ7I56KU0Zwwo4NUX4oFJZEHLbXU5A1PIYQNqhpOSV-fRPasw8rsUFJ5KBFZv668FFY4naeaJGhGtdnmx4Tek_bwY-iFlGlUsJMp3LuTot-mjFGxqUttZ2r3d4eLMlhpnZPxZK0/256fx256f',
#      u'inspect_link': None,
#      u'inspectable': False,
#      u'instance_id': u'0',
#      u'is_listing_allowed': False,
#      u'item_class': None,
#      u'item_ids': [u'14645387751'],
#      u'item_itemset': u'The Spectrum 2 Collection',
#      u'item_quality': u'Base Grade',
#      u'item_rarity': None,
#      u'item_type': u'Container',
#      u'item_weapon': None,
#      u'market_hash_name': u'Spectrum 2 Case',
#      u'number_of_items': 1,
#      u'phase': None,
#      u'recent_sales_info': {u'average_price': u'0.02', u'hours': u'68.65'},
#      u'stickers': None,
#      u'suggested_price': u'0.03',
#      u'tags': {u'category': u'Normal',
#       u'collection': u'The Spectrum 2 Collection',
#       u'quality': u'Base Grade',
#       u'type': u'Container'}}],
#    u'status': u'success',
#    u'total_items': 3}},
#  u'status': u'success'}

# %%
names = [x['market_hash_name'] for x in bs.market_data['prices']]
price = [float(x['price']) for x in bs.market_data['prices']]

# %%
names.index('AWP | Sun in Leo (Minimal Wear)')
# Out:
# 298
